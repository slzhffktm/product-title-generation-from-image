# %%
import import_ipynb
from full_pipeline import predict_io
# Out:
# importing Jupyter notebook from full_pipeline.ipynb
# Using CUDA

# %% [markdown]
# ## Predict

# %%
import pandas as pd

# %%
df = pd.read_csv("data/styles_with_token.csv")

# %%
id_ = 1983
print(df[df.id == id_].tokenized.values)
# Out:
# ["['<start>', 'adidas', 'women', 'graphic', 'blue', 't-shirt', '<end>']"]

# %% [markdown]
# example data: data/images/1892.jpg

# %%
predict_io()
# Out:
# Loading model...
# Use url for input? (Leave blank for False)
#
# Insert image url/file path: (Leave blank to exit) data/images/2116.jpg
# <PIL.Image.Image image mode=RGB size=60x80 at 0x7FD85908EAD0>
# Generated caption: adidas arrow adidas fila adidas fila adidas fila adidas fila adidas fila
# Insert image url/file path: (Leave blank to exit) data/images/2114.jpg
# <PIL.Image.Image image mode=RGB size=60x80 at 0x7FD85908E790>
# Generated caption: adidas fila black adidas black adidas black adidas black adidas black adidas
# Insert image url/file path: (Leave blank to exit) data/images/1892.jpg
# <PIL.Image.Image image mode=RGB size=60x80 at 0x7FD85908E590>
# Generated caption: wildberry reebok urban reebok urban reebok urban reebok urban reebok men reebok
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-dbdbc44129b0> in <module>
# ----> 1 predict_io()
#
# ...
