# %%
import import_ipynb
from full_pipeline import predict_io

# %% [markdown]
# ## Predict

# %% [markdown]
# example data: data/images/1892.jpg

# %%
predict_io()
# Out:
# Loading model...
# Use url for input? (Leave blank for False) yes
#
# Insert image url/file path: (Leave blank to exit) https://s1.bukalapak.com/img/62594955102/w-1000/image___2020_04_03T142046672.png.webp
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7F001FE2FF10>
# Generated caption: puma men navy blue t-shirt
# Insert image url/file path: (Leave blank to exit) https://ecs7.tokopedia.net/img/cache/700/product-1/2019/8/25/354444702/354444702_d23939df-26a6-4cf4-beff-6ae512d80498_1280_1280.jpg
# <PIL.Image.Image image mode=RGB size=700x700 at 0x7F001FE2F750>
# Generated caption: adidas men white and white and white shoe
